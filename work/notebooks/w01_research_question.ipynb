# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
 I chose the Machine Learning lane because i want to understand how computers can learn from data and make intelligent decisions.
AS a computer science student,i believe machine learning is one of the most valuable skills for solving real world problem.
This internship will help me build practical experience,improve my programming and analytical skills, and prepare me for a career in AI and
machine learning
# Out:
#   File "/tmp/ipykernel_701/3313722141.py", line 1
#     skills/README.md I chose the Machine Learning lane because i want to understand how computers can learn from data and make intelligent decisions.
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
The decision in my project is to predict or classify data correctly using a machine learning model. The action is taken by the user or developer based on the models prediction.
 If the recommendation is wrong, it can lead to incorrect decisions, wasted time, reduced accuracy, and loss of trust in the system.
 Therefore, it is important to evaluate and improve the model before using it in real-world applications.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
From the starter CSV, I will focus on a few important values such as the total number of records, the average value of a key feature,
and the number of missing values.These numbers will help me understand the quality of the dataset before building a machine learning model
and decide what preprocessing steps are needed.
# Out:
#   File "/tmp/ipykernel_701/2779140062.py", line 1
#     From the starter CSV, I will focus on a few important values such as the total number of records, the average value of a key feature,
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
My analysis can describe patterns that were observed in the data and provide decision support based on those patterns.
The results can help make informed decisions, but they do not prove that one factor causes another.
The model makes predictions based on the available data, and its recommendations should always be reviewed before
making important real-world decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
